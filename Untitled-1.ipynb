# %%
from ultralytics import YOLO

# %%
model = YOLO("best.pt")

# Dự đoán từ video.mp4
model.predict(source="./videos/yt1s.com - BLKHDPTZ12 Security Camera Parkng Lot Surveillance Video_360P.mp4", show=True, save=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/9484) d:\spacedetection\space_detection\videos\yt1s.com - BLKHDPTZ12 Security Camera Parkng Lot Surveillance Video_360P.mp4: 384x640 40 cars, 96.1ms
# video 1/1 (frame 2/9484) d:\spacedetection\space_detection\videos\yt1s.com - BLKHDPTZ12 Security Camera Parkng Lot Surveillance Video_360P.mp4: 384x640 40 cars, 80.7ms
# ...
